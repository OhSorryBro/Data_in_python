# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
# !type examples\ex1.csv
df = pd.read_csv('examples/ex1.csv')
df
print('===')
# !type examples\ex2.csv
pd.read_csv('examples/ex2.csv', header=None)
pd.read_csv('examples/ex2.csv',names=['a','b','c','d','message'])

names =['a','b','c','d','message']
pd.read_csv('examples/ex2.csv',names=names,index_col='message')
# Out:
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo
# ===
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %%
# !type examples\csv_mindex.csv
parsed = pd.read_csv('examples/csv_mindex.csv',index_col=['key1','key2'])
parsed
# !type examples\ex3.txt
result = pd.read_table('examples/ex3.txt',sep='\s+')
print('===')
# !type examples\ex4.csv
pd.read_csv('examples/ex4.csv',skiprows=[0,2,3])
print('===')
# !type examples\ex5.csv
result = pd.read_csv('examples/ex5.csv')
result
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Michał\AppData\Local\Temp\ipykernel_11572\3785923276.py:5: SyntaxWarning: invalid escape sequence '\s'
#   result = pd.read_table('examples/ex3.txt',sep='\s+')
# key1,key2,value1,value2
# one,a,1,2
# one,b,3,4
# one,c,5,6
# one,d,7,8
# two,a,9,10
# two,b,11,12
# two,c,13,14
# two,d,15,16
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491
# ===
# # Cześć!
# a,b,c,d,message
# # Chciałem tylko trochę utrudnić Twoją pracę.
# # Kto w ogóle wczytuje pliki CSV za pomocą komputera?
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo
# ===
# something,a,b,c,d,message
# one,1,2,3,4,NA
# two,5,6,,8,world
# three,9,10,11,12,foo
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
pd.isnull(result)
result = pd.read_csv('examples/ex5.csv', na_values=['NULL'])
result
result2 = pd.read_csv('examples/ex5.csv', keep_default_na=False)
result2
result2.isna()
result3 = pd.read_csv('examples/ex5.csv', keep_default_na=False, na_values=['NA'])
result3
result3.isna()
sentinels = {'message':['foo','NA'],'something':['two']}
pd.read_csv('examples/ex5.csv', na_values=sentinels, keep_default_na=False)
# Out:
#   something  a   b   c   d message
# 0       one  1   2   3   4     NaN
# 1       NaN  5   6       8   world
# 2     three  9  10  11  12     NaN

# %%
pd.options.display.max_rows = 10
result = pd.read_csv('examples/ex6.csv')
result
pd.read_csv('examples/ex6.csv', nrows=5)
chunker = pd.read_csv('examples/ex6.csv',chunksize=1000)
type(chunker)
tot = pd.Series([],dtype='int64')
for piece in chunker:
    tot = tot.add(piece['key'].value_counts(),fill_value=0)
tot = tot.sort_values(ascending=False)
tot[:10]
data = pd.read_csv('examples/ex5.csv')
data
data.to_csv('examples/out.csv')
# !type examples\out.csv
print('===')
import sys
data.to_csv(sys.stdout, sep='|')
print('===')
data.to_csv(sys.stdout, na_rep='NULL')
print('+++')
data.to_csv(sys.stdout, index=False, header=False)
print('+++')
data.to_csv(sys.stdout,index=False,columns=['a','b','c'])
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,
# 1,two,5,6,,8,world
# 2,three,9,10,11.0,12,foo
# ===
# |something|a|b|c|d|message
# 0|one|1|2|3.0|4|
# 1|two|5|6||8|world
# 2|three|9|10|11.0|12|foo
# ===
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,NULL
# 1,two,5,6,NULL,8,world
# 2,three,9,10,11.0,12,foo
# +++
# one,1,2,3.0,4,
# two,5,6,,8,world
# three,9,10,11.0,12,foo
# +++
# a,b,c
# 1,2,3.0
# 5,6,
# 9,10,11.0

# %%
# !type examples\ex7.csv
import csv
f=open('examples/ex7.csv')
reader = csv.reader(f)
print('xxx')
for line in reader:
    print(line)

f.close()

with open('examples/ex7.csv') as f:
    lines = list(csv.reader(f))
header, values = lines[0], lines[1:]
data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict
class my_dialect(csv.Dialect):
    lineterminator ='\n'
    delimiter =';'
    quotechar ='"'
    quoting = csv.QUOTE_MINIMAL

print("xxx")
with open('examples/ex7.csv') as f:
    reader = csv.reader(f, dialect=my_dialect)
    for line in reader:
        print(line)
print("xxx")
with open('examples/ex7.csv') as f:
    reader = csv.reader(f, delimiter='|')
    for line in reader:
        print(line)
print('_)_)')
with open('mydata.csv','w') as f:
    writer = csv.writer(f, dialect=my_dialect)
    writer.writerow(('one','two','three'))
    writer.writerow(('1','2','3'))
    writer.writerow(('4','5','6'))
    writer.writerow(('7','8','9'))
# Out:
# "a","b","c"
# "1","2","3"
# "1","2","3"
# xxx
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']
# xxx
# ['a,"b","c"']
# ['1,"2","3"']
# ['1,"2","3"']
# xxx
# ['a,"b","c"']
# ['1,"2","3"']
# ['1,"2","3"']
# _)_)

# %%
obj = '''
{"name": "Wes",
 "cities_lived": ["Akron", "Nashville", "New York", "San Francisco"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 34, "hobbies": ["guitars", "soccer"]},
              {"name": "Katie", "age": 42, "hobbies": ["diving", "art"]}]
}
'''
import json
result = json.loads(obj)
result
asjson = json.dumps(result)
asjson
siblings = pd.DataFrame(result['siblings'], columns=['name','age'])
siblings
# !type examples\example.json
data = pd.read_json('examples/example.json')
data
data.to_json(sys.stdout)
data.to_json(sys.stdout, orient='records')
# Out:
# [{"a": 1, "b": 2, "c": 3},
#  {"a": 4, "b": 5, "c": 6},
#  {"a": 7, "b": 8, "c": 9}]
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}[{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]

# %%
tables = pd.read_html('examples/fdic_failed_bank_list.html')
len(tables)
failures = tables[0]
failures.head()
close_timestamps = pd.to_datetime(failures['Closing Date'])
close_timestamps.dt.year.value_counts()
# Out:
# Closing Date
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
#        ...
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: count, Length: 15, dtype: int64

# %%
from lxml import objectify
import pandas as pd

# --- XML ---
path = 'data/mta_perf/Performance_MNR.xml'
with open(path) as f:
    root = objectify.parse(f).getroot()

data = []
skip_fields = ['PARENT_SEQ', 'INDICATOR_SEQ', 'DESIRED_CHANGE', 'DECIMAL_PLACES']
for elt in root.INDICATOR:
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)
perf = pd.DataFrame(data)

perf2 = pd.read_xml(path)
perf2.head()

# --- CSV + pickle ---
frame = pd.read_csv('examples/ex1.csv')
frame.to_pickle('examples/frame_pickle')
pd.read_pickle('examples/frame_pickle')

# --- parquet ---
fec = pd.read_parquet('datasets/fec/fec.parquet')
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[91], line 29
#      25 frame.to_pickle('examples/frame_pickle')
#      26 pd.read_pickle('examples/frame_pickle')
#      27
#      28 # --- parquet ---
# ---> 29 fec = pd.read_parquet('datasets/fec/fec.parquet')
#
# File d:\Basics of programming\Data_in_python\Data_in_python\.venv\Lib\site-packages\pandas\io\parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)    518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
#     521     Load a parquet object from the file path, returning a DataFrame.
#     522
#    (...)    665     1    4    9
#     666     """
# --> 668     impl = get_engine(engine)
#     669     check_dtype_backend(dtype_backend)
#     671     return impl.read(
#     672         path,
#     673         columns=columns,
#    (...)    679         **kwargs,
#     680     )
#
# File d:\Basics of programming\Data_in_python\Data_in_python\.venv\Lib\site-packages\pandas\io\parquet.py:64, in get_engine(engine)
#      62 for engine_class in engine_classes:
#      63     try:
# ---> 64         return engine_class()
#      65     except ImportError as err:
#      66         error_msgs += "\n - " + str(err)
#
# File d:\Basics of programming\Data_in_python\Data_in_python\.venv\Lib\site-packages\pandas\io\parquet.py:170, in PyArrowImpl.__init__(self)
#     167 import pyarrow.parquet
#     169 # import utils to register the pyarrow extension types
# --> 170 import pandas.core.arrays.arrow.extension_types  # pyright: ignore[reportUnusedImport] # noqa: F401
#     172 self.api = pyarrow
#
# File d:\Basics of programming\Data_in_python\Data_in_python\.venv\Lib\site-packages\pandas\core\arrays\arrow\extension_types.py:59
#      57 # register the type with a dummy instance
#      58 _period_type = ArrowPeriodType("D")
# ---> 59 pyarrow.register_extension_type(_period_type)
#      62 class ArrowIntervalType(pyarrow.ExtensionType):
#      63     def __init__(self, subtype, closed: IntervalClosedType) -> None:
#      64         # attributes need to be set first before calling
#      65         # super init (as that calls serialize)
#
# File pyarrow/types.pxi:2226, in pyarrow.lib.register_extension_type()
# -> 2226 'Could not get source, probably due dynamically evaluated source code.'
#
# File pyarrow/error.pxi:92, in pyarrow.lib.check_status()
# ---> 92 'Could not get source, probably due dynamically evaluated source code.'
#
# ArrowKeyError: A type extension with name pandas.period already defined

# %%
import pandas as pd, pyarrow
print(pd.__version__, pyarrow.__version__)
# Out:
# 3.0.3 24.0.0

# %%
# %pip install -U pyarrow
# Out:
# Requirement already satisfied: pyarrow in d:\basics of programming\data_in_python\data_in_python\.venv\lib\site-packages (24.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
print(pd.read_parquet('data/fec/fec.parquet').shape)
# Out:
# (1001731, 16)

# %%
xlsx = pd.ExcelFile('examples/ex1.xlsx')
xlsx.sheet_names
xlsx.parse(sheet_name='Sheet1')
xlsx.parse(sheet_name='Sheet1',index_col=0)
frame = pd.read_excel('examples/ex1.xlsx','Sheet1')
frame
with pd.ExcelWriter('examples/ex2.xlsx') as writer:
    frame.to_excel(writer, sheet_name='Sheet1')

# %%
import tables
tables.file._open_files.close_all()
pd.read_hdf('examples/mydata.h5', 'obj3', where=['index < 5'])
frame = pd.DataFrame({'a': np.random.standard_normal(100)})
store = pd.HDFStore('examples/mydata.h5')
store['obj1'] = frame
store['obj1_col'] = frame['a']
store['obj1']
store.put('obj2', frame, format='table')
store.select('obj2', where=['index >= 10 and index <= 15'])
store.close()
frame.to_hdf('examples/mydata.h5', key='obj3', format='table')
pd.read_hdf('examples/mydata.h5', 'obj3', where=['index < 5'])
# Out:
# d:\Basics of programming\Data_in_python\Data_in_python\.venv\Lib\site-packages\tables\file.py:130: UnclosedFileWarning: Closing remaining open file: examples/mydata.h5
#   warnings.warn(UnclosedFileWarning(msg))
#           a
# 0 -0.552969
# 1  1.083390
# 2  0.252914
# 3 -0.175613
# 4  1.329141

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp.raise_for_status()
resp
data = resp.json()
data[0]['title']
issues = pd.DataFrame(data, columns=['number','title','labels','state'])
issues
# Out:
#     number                                              title  \
# 0    65913  BUG: Preserve None when replacing NaN in strin...
# 1    65912  STY: Update min versions pre-commit hook to al...
# 2    65911           DEPR: by_blocks in tm.assert_frame_equal
# 3    65910  BUG: idxmin/idxmax with skipna=False returned ...
# 4    65909  Backport PR #65840 on branch 3.0.x (PERF: Big ...
# 5    65907  BUG: preserve dtype for NA columns with fill_v...
# 6    65905  [BUG] NULL pointer dereference in total_second...
# 7    65904  [BUG] NULL pointer dereference in get_long_att...
# 8    65903  [BUG] Use-after-free in int64ToIso: result fre...
# 9    65902  BUG: Series.dt.isocalendar() not preserving in...
# 10   65901  fix: to_hdf parent key no longer deletes neste...
# 11   65900  BUG: fix incorrect column name for index when ...
# 12   65899  BUG: merge with NaN-labeled join key produces ...
# 13   65895  failing tests when building pandas 2.3.3 with ...
# 14   65894  BUG: Series.dt.isocalendar() does not align in...
# 15   65893  BUG: improve error message for non-string dtyp...
# 16   65892            BUG: Inconsistent nan to None behaviour
# 17   65891  DOC: Page not found error for versions 1.4 and...
# 18   65885  PERF: Speed up `import pandas` with PEP 810 la...
# 19   65881  DEPR: Series.dt.freq returning a string instea...
# 20   65877  DEPR: deprecate DataFrame construction from ra...
# 21   65875  ENH: Support %N directive in strptime parsing ...
# 22   65873               Bugfix/57925 bytes categorical index
# 23   65869  BUG: to_json not warning about deprecated epoc...
# 24   65868  BUG: missing deprecation warning about epoch t...
# 25   65867      CLN: remove the deprecated is_sparse function
# 26   65866  BUG: to_json raising OverflowError for Period ...
# 27   65863  ENH: Support %N directive in strptime parsing ...
# 28   65862  BUG: raise helpful errors for unsupported pyar...
# 29   65859  BUG: fix read_csv pyarrow engine column-name a...
#
#                                                labels state
# 0                                                  []  open
# 1   [{'id': 106935113, 'node_id': 'MDU6TGFiZWwxMDY...  open
# 2   [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 3   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 4   [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 5                                                  []  open
# 6                                                  []  open
# 7                                                  []  open
# 8                                                  []  open
# 9                                                  []  open
# 10                                                 []  open
# 11                                                 []  open
# 12                                                 []  open
# 13  [{'id': 129350, 'node_id': 'MDU6TGFiZWwxMjkzNT...  open
# 14  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 15                                                 []  open
# 16  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 17  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 18                                                 []  open
# 19  [{'id': 53181044, 'node_id': 'MDU6TGFiZWw1MzE4...  open
# 20  [{'id': 87485152, 'node_id': 'MDU6TGFiZWw4NzQ4...  open
# 21                                                 []  open
# 22                                                 []  open
# 23  [{'id': 49379259, 'node_id': 'MDU6TGFiZWw0OTM3...  open
# 24  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 25  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 26                                                 []  open
# 27  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 28  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 29  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open

# %%
import sqlite3
query="""
CREATE TABLE test
(a VARCHAR(20), b VARCHAR(20),
c REAL, d INTEGER);
"""
con = sqlite3.connect('mydata.sqlite')
con.execute(query)
con.commit()

# %%
data =[('Atlanta','Georgia',1.25,6),
       ('Tallahassee','Florida',2.6,3),
       ('Sacramento','California',1.7,5)]
stmt = 'INSERT INTO test VALUES(?,?,?,?)'
con.executemany(stmt,data)
con.commit()

# %%
cursor = con.execute('select * from test')
rows = cursor.fetchall()
rows
cursor.description
pd.DataFrame(rows,columns=[x[0] for x in cursor.description])
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5
# 3      Atlanta     Georgia  1.25  6
# 4  Tallahassee     Florida  2.60  3
# 5   Sacramento  California  1.70  5
# 6      Atlanta     Georgia  1.25  6
# 7  Tallahassee     Florida  2.60  3
# 8   Sacramento  California  1.70  5

# %%
import sqlalchemy as sqla
db = sqla.create_engine('sqlite:///mydata.sqlite')
pd.read_sql('select * from test',db)
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5
# 3      Atlanta     Georgia  1.25  6
# 4  Tallahassee     Florida  2.60  3
# 5   Sacramento  California  1.70  5
# 6      Atlanta     Georgia  1.25  6
# 7  Tallahassee     Florida  2.60  3
# 8   Sacramento  California  1.70  5

# %%
In [1]: b = [1,2,3]
In [2]: an_apple = 52
In [3]: print("dodo")

def add_numbers(a,b):
    """"Sum 2 values"""
    return a+b
add_numbers

In [4]: list(range(5, 0, -1))
# Out:
# dodo
# [5, 4, 3, 2, 1]

# %%
In [1]: b = [1,2,3]
In [2]: an_apple = 52
In [3]: print?

def add_numbers(a,b):
    """"Sum 2 values"""
    return a+b
add_numbers?
# Out:
# Signature: add_numbers(a, b)
# Docstring: "Sum 2 values
# File:      c:\users\michał\appdata\local\temp\ipykernel_12112\2443753355.py
# Type:      function
